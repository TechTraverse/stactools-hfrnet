# %% [markdown]
# # stactools-hfrnet
#
# This is a small notebook demonstrating use of this package and its generated items and collections.
# It is intended to be executed from the root of this repository, since it relies on files that have been checked into this repo.

# %% [markdown]
# ## Example items and collections
#
# This package provides some example data, in the `examples/` directory.
# You can load them with [pystac](https://github.com/stac-utils/pystac).
# The item includes a custom attribute that is specific to this package.

# %%
from pathlib import Path

from IPython.display import display
from pystac import Collection

import stactools.hfrnet.stac

root = Path().cwd().parent
collection = Collection.from_file(str(root / "examples" / "collection.json"))
display(collection)
item = next(collection.get_items())
display(item)
print(f"This is the custom attribute: {item.properties['custom_attribute']}")
# Out:
# <Collection id=example-collection>
# <Item id=example-item>
# This is the custom attribute: foo

# %% [markdown]
# ## Creating items and collections
#
# Items can be created from an href to a single tif file.
# Items are added to collections using the standard pystac interface.

# %%
tif_path = root / "tests" / "data" / "asset.tif"
item = stactools.hfrnet.stac.create_item(str(tif_path))
collection = stactools.hfrnet.stac.create_collection()
collection.add_item(item)
display(collection)
# Out:
# <Collection id=example-collection>

# %%
import netCDF4

src = netCDF4.Dataset(
    "../tests/data/rtv-ushi-6km-25h-avg_v1r0_hfr_s20230103120000_e20230103120000_c20250107174501.nc"
)

for name, variable in src.variables.items():
    print(f"variable: {name}")
    for attrname in variable.ncattrs():
        print("{} -- {}".format(attrname, getattr(variable, attrname)))
        # or :
        # print("{} -- {}".format(attrname, variable.getncattr(attrname)))


src = netCDF4.MFDataset("../tests/data/*.nc")

for name, variable in src.variables.items():
    for attrname in variable.ncattrs():
        print("{} -- {}".format(attrname, getattr(variable, attrname)))
# Out:
# variable: time
# standard_name -- time
# units -- seconds since 1970-01-01
# calendar -- gregorian
# bounds -- time_bnds
# variable: lat
# standard_name -- latitude
# units -- degrees_north
# variable: lon
# standard_name -- longitude
# units -- degrees_east
# variable: time_bnds
# variable: depth
# standard_name -- depth
# units -- m
# bounds -- depth_bnds
# comment --
#  ['Nominal depth (and corresponding bounds) based on contributing radars']
# variable: depth_bnds
# variable: wgs84
# grid_mapping_name -- latitude_longitude
# longitude_of_prime_meridian -- 0.0
# semi_major_axis -- 6378137.0
# inverse_flattening -- 298.257223563
# variable: u_mean
# _FillValue -- -32767
# standard_name -- surface_eastward_sea_water_velocity
# long_name -- mean eastward surface velocity
# units -- m s-1
# scale_factor -- 0.009999999776482582
# grid_mapping -- wgs84
# coordinates -- depth
# cell_methods -- depth: mean time: mean (interval: 1 hour comment: 1 hour average)
# ancillary_variables -- n_obs
# variable: v_mean
# _FillValue -- -32767
# standard_name -- surface_northward_sea_water_velocity
# long_name -- mean northward surface velocity
# units -- m s-1
# scale_factor -- 0.009999999776482582
# grid_mapping -- wgs84
# coordinates -- depth
# cell_methods -- depth: mean time: mean (interval: 1 hour comment: 1 hour average)
# ancillary_variables -- n_obs
# variable: u_var
# _FillValue -- -32767
# standard_name -- surface_eastward_sea_water_velocity
# long_name -- eastward surface velocity variance
# units -- m2 s-2
# scale_factor -- 9.999999747378752e-05
# grid_mapping -- wgs84
# coordinates -- depth
# cell_methods -- depth: mean time: variance (interval: 1 hour comment: 1 hour average)
# ancillary_variables -- n_obs
# variable: v_var
# _FillValue -- -32767
# standard_name -- surface_northward_sea_water_velocity
# long_name -- northward surface velocity variance
# units -- m2 s-2
# scale_factor -- 9.999999747378752e-05
# grid_mapping -- wgs84
# coordinates -- depth
# cell_methods -- depth: mean time: variance (interval: 1 hour comment: 1 hour average)
# ancillary_variables -- n_obs
# variable: u_min
# _FillValue -- -32767
# standard_name -- surface_eastward_sea_water_velocity
# long_name -- minimum eastward surface velocity
# units -- m s-1
# scale_factor -- 0.009999999776482582
# grid_mapping -- wgs84
# coordinates -- depth
# cell_methods -- depth: mean time: minimum (interval: 1 hour comment: 1 hour average)
# ancillary_variables -- n_obs
# variable: v_min
# _FillValue -- -32767
# standard_name -- surface_northward_sea_water_velocity
# long_name -- minimum northward surface velocity
# units -- m s-1
# scale_factor -- 0.009999999776482582
# grid_mapping -- wgs84
# coordinates -- depth
# cell_methods -- depth: mean time: minimum (interval: 1 hour comment: 1 hour average)
# ancillary_variables -- n_obs
# variable: u_max
# _FillValue -- -32767
# standard_name -- surface_eastward_sea_water_velocity
# long_name -- maximum eastward surface velocity
# units -- m s-1
# scale_factor -- 0.009999999776482582
# grid_mapping -- wgs84
# coordinates -- depth
# cell_methods -- depth: mean time: maximum (interval: 1 hour comment: 1 hour average)
# ancillary_variables -- n_obs
# variable: v_max
# _FillValue -- -32767
# standard_name -- surface_northward_sea_water_velocity
# long_name -- maximum northward surface velocity
# units -- m s-1
# scale_factor -- 0.009999999776482582
# grid_mapping -- wgs84
# coordinates -- depth
# cell_methods -- depth: mean time: maximum (interval: 1 hour comment: 1 hour average)
# ancillary_variables -- n_obs
# variable: n_obs
# _FillValue -- -32767
# standard_name -- number_of_observations
# units -- count
# grid_mapping -- wgs84
# coordinates -- depth
# cell_methods -- time: sum (interval: 1 hour)
# variable: processing_parameters
# long_name -- Methods and parameters used to compute subtidal current
# combine_method_name -- Unweighted Least Squares
# combine_method_description -- Method used to compute hourly total solutions from radial velocities
# min_temporal_coverage -- 18
# min_temporal_coverage_description -- Minimum number of hours required to compute a subtidal current
# max_hdop -- 1.25
# max_hdop_description -- Maximum allowed hourly vector HDOP
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[8], line 13
#       8         print("{} -- {}".format(attrname, getattr(variable, attrname)))
#       9         # or :
#      10         #print("{} -- {}".format(attrname, variable.getncattr(attrname)))
# ---> 13 src = netCDF4.MFDataset("../tests/data/*.nc")
#      15 for name, variable in src.variables.items():
#      16     for attrname in variable.ncattrs():
#
# File src/netCDF4/_netCDF4.pyx:7018, in netCDF4._netCDF4.MFDataset.__init__()
#
# KeyError: 'u_mean'
